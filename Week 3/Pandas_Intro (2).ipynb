# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas is a Python library for handeling table data
#
# Pandas stands for "Panel Data"
#
# Crated in 2008
#
# Primarily written in C++
#
# Built on top of Numpy Arrays

# %% [markdown]
# Pandas Series

# %%
pets_list = ["Dog", "Cat", "Lizard", "Parrot", "Fish", "Snake", "Rock"]

pets = pd.Series(pets_list)
pets
# Out:
# 0       Dog
# 1       Cat
# 2    Lizard
# 3    Parrot
# 4      Fish
# 5     Snake
# 6      Rock
# dtype: object

# %%
print(pets.index)
print(pets[3])
# Out:
# RangeIndex(start=0, stop=7, step=1)
# Parrot

# %%
pets_food_price = [20.00, 15.00, 5.00, 10.00, 5.00, 20.00, None]

food = pd.Series(pets_food_price, index=pets_list)
food
# Out:
# Dog       20.0
# Cat       15.0
# Lizard     5.0
# Parrot    10.0
# Fish       5.0
# Snake     20.0
# Rock       NaN
# dtype: float64

# %%
food
# Out:
# Dog       20.0
# Cat       15.0
# Lizard     5.0
# Parrot    10.0
# Fish       5.0
# Snake     20.0
# Rock       NaN
# dtype: float64

# %% [markdown]
# .loc[ ]
#
# .iloc[ ]

# %%
food.loc[["Dog", "Parrot"]]
# Out:
# Dog       20.0
# Parrot    10.0
# dtype: float64

# %%
food.loc[ food <= 15 ]
# Out:
# Cat       15.0
# Lizard     5.0
# Parrot    10.0
# Fish       5.0
# dtype: float64

# %%
food.loc["Parrot"]
# Out:
# 10.0

# %%
food.iloc[3]
# Out:
# 10.0

# %%
food.sort_values(ascending=False).iloc[0:3]
# Out:
# Dog      20.0
# Snake    20.0
# Cat      15.0
# dtype: float64

# %%
food.sort_values().iloc[0:3]
# Out:
# Lizard     5.0
# Fish       5.0
# Parrot    10.0
# dtype: float64

# %%
food.filter(["Parrot", "Snake"])
# Out:
# Parrot    10.0
# Snake     20.0
# dtype: float64

# %%
food[["Rock"]]
# Out:
# Rock   NaN
# dtype: float64

# %%
food
# Out:
# Dog       20.0
# Cat       15.0
# Lizard     5.0
# Parrot    10.0
# Fish       5.0
# Snake     20.0
# Rock       NaN
# dtype: float64

# %%
food.fillna(food[["Fish", "Lizard"]].mean())
# Out:
# Dog       20.0
# Cat       15.0
# Lizard     5.0
# Parrot    10.0
# Fish       5.0
# Snake     20.0
# Rock       5.0
# dtype: float64

# %%
food["Dog"] = 17.0

# %%
food
# Out:
# Dog       17.0
# Cat       15.0
# Lizard     5.0
# Parrot    10.0
# Fish       5.0
# Snake     20.0
# Rock       NaN
# dtype: float64

# %%
food["Canary"] = 7.00

# %%
food
# Out:
# Dog       17.0
# Cat       15.0
# Lizard     5.0
# Parrot    10.0
# Fish       5.0
# Snake     20.0
# Rock       NaN
# Canary     7.0
# dtype: float64

# %%
# ["Dog", "Cat", "Lizard", "Parrot", "Fish", "Snake", "Rock"]
classification = ["Mammal", "Mammal", "Reptile", "Bird", "Fish", "Reptile", None]

# %%
print(len(classification),len(pets))
# Out:
# 7 7

# %%
kind_of_animal = pd.Series(classification, index = pets)
kind_of_animal
# Out:
# Dog        Mammal
# Cat        Mammal
# Lizard    Reptile
# Parrot       Bird
# Fish         Fish
# Snake     Reptile
# Rock         None
# dtype: object

# %%
kind_of_animal.str.upper()
# Out:
# Dog        MAMMAL
# Cat        MAMMAL
# Lizard    REPTILE
# Parrot       BIRD
# Fish         FISH
# Snake     REPTILE
# Rock         None
# dtype: object

# %%
kind_of_animal.groupby(by=kind_of_animal).count()
# Out:
# Bird       1
# Fish       1
# Mammal     2
# Reptile    2
# dtype: int64

# %%
kind_of_animal.unique()
# Out:
# array(['Mammal', 'Reptile', 'Bird', 'Fish', None], dtype=object)

# %%
len(food), food.count()
# Out:
# (8, 7)

# %%
type(food["Rock"])
# Out:
# numpy.float64

# %% [markdown]
# 1) Define a function that returns a Numpy Array of the Fibonacci sequence up to a given number
#
# 2) Define a function thar retruns a Numpy array of a Factorial sequence up to a given number
#
# Bonus) Make it more efficient

# %%
def fib(x):
  fibl = [0,1]

  while fibl[-1] <= x:
    fibl.append(fibl[-1] + fibl[-2])
  return np.array(fibl[:-1])

fib(0)
# Out:
# array([0])

# %%
def fact(x):
  factl = [1]
  y = 2
  while factl[-1] <= x:
    factl.append(factl[-1] * y)
    y = y + 1
  return np.array(factl[:-1])

fact(10)
# Out:
# array([1, 2, 6])

# %%
def fac_array(x:int) -> np.array:
    # factorial of 0 = 1
    if x == 0:
        return np.array([1])
    fac_list = [1]
    # iterate through each number up to given number adding to list
    for i in range(1,x+1):
        product = 1
        for j in range(i,0,-1):
            product *=j
        fac_list.append(product)
    # have to use array of python objects because int can't handle the size
    return np.array(fac_list)
fac_array(10)
# Out:
# array([      1,       1,       2,       6,      24,     120,     720,
#           5040,   40320,  362880, 3628800])

# %% [markdown]
# DataFrame

# %%
pet_index = ["dog", "cat", "parrot"]
pet_data = [
    {
        "food": 20.00,
        "class": "mammal"
    },
    {
        "food": 15.00,
        "class": "mammal"
    },
    {
        "food": 10.00,
        "class": "bird"
    },
]
pet_data
# Out:
# [{'food': 20.0, 'class': 'mammal'},
#  {'food': 15.0, 'class': 'mammal'},
#  {'food': 10.0, 'class': 'bird'}]

# %%
pet_df = pd.DataFrame(pet_data, index=pet_index)
pet_df
# Out:
#         food   class
# dog     20.0  mammal
# cat     15.0  mammal
# parrot  10.0    bird

# %%
pet_index2 = ["lizard", "snake", "fish"]
pet_data2 = {
    "food": [5.00,20.00,5.00],
    "class": ["reptile", "reptile", "fish"]
}

# %%
pet_df2 = pd.DataFrame(pet_data2, index=pet_index2)
pet_df2
# Out:
#         food    class
# lizard   5.0  reptile
# snake   20.0  reptile
# fish     5.0     fish

# %%
pet_df['class']
# Out:
# dog       mammal
# cat       mammal
# parrot      bird
# Name: class, dtype: object

# %%
pet_df['food']
# Out:
# dog       20.0
# cat       15.0
# parrot    10.0
# Name: food, dtype: float64

# %%
kind_of_animal
# Out:
# Dog        Mammal
# Cat        Mammal
# Lizard    Reptile
# Parrot       Bird
# Fish         Fish
# Snake     Reptile
# Rock         None
# dtype: object

# %%
df = pd.DataFrame({"food":food, "class": kind_of_animal}, index=food.index)
df
# Out:
#         food    class
# Dog     17.0   Mammal
# Cat     15.0   Mammal
# Lizard   5.0  Reptile
# Parrot  10.0     Bird
# Fish     5.0     Fish
# Snake   20.0  Reptile
# Rock     NaN     None
# Canary   7.0      NaN

# %%
df["size"] = ["large", "medium", "small", "medium", "small", "medium", "small", "small"]
df
# Out:
#         food    class    size
# Dog     17.0   Mammal   large
# Cat     15.0   Mammal  medium
# Lizard   5.0  Reptile   small
# Parrot  10.0     Bird  medium
# Fish     5.0     Fish   small
# Snake   20.0  Reptile  medium
# Rock     NaN     None   small
# Canary   7.0      NaN   small

# %%
df[["food","size"]]
# Out:
#         food    size
# Dog     17.0   large
# Cat     15.0  medium
# Lizard   5.0   small
# Parrot  10.0  medium
# Fish     5.0   small
# Snake   20.0  medium
# Rock     NaN   small
# Canary   7.0   small

# %%
df.loc["Dog"]
# Out:
# food       17.0
# class    Mammal
# size      large
# Name: Dog, dtype: object

# %%
df.loc[["Dog","Lizard"]]
# Out:
#         food    class   size
# Dog     17.0   Mammal  large
# Lizard   5.0  Reptile  small

# %%
df.iloc[1:3]
# Out:
#         food    class    size
# Cat     15.0   Mammal  medium
# Lizard   5.0  Reptile   small

# %%
amz = pd.read_csv("./amazon_prime_titles.csv")
amz.head(3)
# Out:
#   show_id   type                 title      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
#
#                                          description
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# ...

# %%
amz.set_index("show_id", inplace=True)
# amz = amz.set_index("show_id")
amz.head()
# Out:
#           type                 title        director  \
# show_id
# s1       Movie   The Grand Seduction    Don McKellar
# s2       Movie  Take Care Good Night    Girish Joshi
# s3       Movie  Secrets of Deception     Josh Webber
# s4       Movie    Pink: Staying True  Sonia Anderson
# s5       Movie         Monster Maker    Giles Foster
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# s3       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# s4       Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# s5       Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#              date_added  release_year rating duration  \
# show_id
# s1       March 30, 2021          2014    NaN  113 min
# ...

# %%
amz["type"].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
tv_df = amz[amz["type"] == "TV Show"]
tv_df.head()
# Out:
#             type                          title director  \
# show_id
# s18      TV Show                     Zoo Babies      NaN
# s19      TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# s21      TV Show                     Zoboomafoo      NaN
# s22      TV Show      Zo Zo Zombie: Mini-Series      NaN
# s24      TV Show                   ZeroZeroZero      NaN
#
#                                                       cast country date_added  \
# show_id
# s18                             Narrator - Gillian Barlett     NaN        NaN
# s19                                        Zoë Coombs Marr     NaN        NaN
# s21                                                    NaN     NaN        NaN
# s22      Alex Cazares, Ben Diskin, Cristina Vee, Erika ...     NaN        NaN
# s24      ANDREA RISEBOROUGH, HAROLD TORRES, CLAUDIA PIN...   Italy        NaN
#
#          release_year rating  duration                      listed_in  \
# show_id
# ...

# %%
movie_df = amz[amz["type"] == "Movie"]
movie_df.head()
# Out:
#           type                 title        director  \
# show_id
# s1       Movie   The Grand Seduction    Don McKellar
# s2       Movie  Take Care Good Night    Girish Joshi
# s3       Movie  Secrets of Deception     Josh Webber
# s4       Movie    Pink: Staying True  Sonia Anderson
# s5       Movie         Monster Maker    Giles Foster
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# s3       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# s4       Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# s5       Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#              date_added  release_year rating duration  \
# show_id
# s1       March 30, 2021          2014    NaN  113 min
# ...

# %%
movie_df["duration"].str.len()
# Out:
# show_id
# s1       7
# s2       7
# s3       6
# s4       6
# s5       6
#         ..
# s9661    6
# s9663    6
# s9664    6
# s9666    6
# s9668    7
# Name: duration, Length: 7814, dtype: int64

# %%
movie_df[movie_df["duration"].str.len() == 7]
# Out:
#           type                      title                     director  \
# show_id
# s1       Movie        The Grand Seduction                 Don McKellar
# s2       Movie       Take Care Good Night                 Girish Joshi
# s8       Movie               Grease Live!  Thomas Kail, Alex Rudzinski
# s20      Movie                        Zoe                Drake Doremus
# s37      Movie             You're Not You              George C. Wolfe
# ...        ...                        ...                          ...
# s9650    Movie                       Jack         Francis Ford Coppola
# s9653    Movie            Famo$o (4K UHD)               Pepsy Romanoff
# s9654    Movie  Date Night (Extended Cut)                   Shawn Levy
# s9657    Movie         Anaganaga Oka Nenu                     Vamshi P
# s9668    Movie                Harry Brown                Daniel Barber
#
#                                                       cast        country  \
# show_id
# ...

# %%
# movie_df = movie_df.copy()
movie_df["duration"].str.split(expand=True)[0].astype(int)
# Out:
# show_id
# s1       113
# s2       110
# s3        74
# s4        69
# s5        45
#         ...
# s9661     96
# s9663     93
# s9664     60
# s9666     90
# s9668    103
# Name: 0, Length: 7814, dtype: int64

# %%
movie_df["duration_min"] = movie_df["duration"].str.split(expand=True)[0].astype(int)
movie_df.head()
# Out:
#           type                 title        director  \
# show_id
# s1       Movie   The Grand Seduction    Don McKellar
# s2       Movie  Take Care Good Night    Girish Joshi
# s3       Movie  Secrets of Deception     Josh Webber
# s4       Movie    Pink: Staying True  Sonia Anderson
# s5       Movie         Monster Maker    Giles Foster
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# s3       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# s4       Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# s5       Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#              date_added  release_year rating duration  \
# show_id
# s1       March 30, 2021          2014    NaN  113 min
# ...

# %%
movie_df[movie_df['duration_min'] >= 100 ].head()
# Out:
#           type                 title                     director  \
# show_id
# s1       Movie   The Grand Seduction                 Don McKellar
# s2       Movie  Take Care Good Night                 Girish Joshi
# s8       Movie          Grease Live!  Thomas Kail, Alex Rudzinski
# s20      Movie                   Zoe                Drake Doremus
# s37      Movie        You're Not You              George C. Wolfe
#
#                                                       cast        country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# s8       Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...  United States
# s20      Ewan McGregor, Léa Seydoux, Theo James, Mirand...            NaN
# s37                Hilary Swank, Emmy Rossum, Josh Duhamel            NaN
#
#              date_added  release_year rating duration             listed_in  \
# show_id
# ...

# %%
tv_df[(tv_df["release_year"] == 2000) | (tv_df["release_year"] == 2001)].head()
# Out:
#             type               title director  \
# show_id
# s21      TV Show          Zoboomafoo      NaN
# s845     TV Show   Supermarket Sweep      NaN
# s906     TV Show  Star Trek: Voyager      NaN
# s1172    TV Show        Rex the Runt      NaN
# s1231    TV Show       Queer as Folk      NaN
#
#                                                       cast country date_added  \
# show_id
# s21                                                    NaN     NaN        NaN
# s845                                        David Ruprecht     NaN        NaN
# s906     Kate Mulgrew, Robert Beltran, Roxann Biggs-Daw...     NaN        NaN
# s1172                                                  NaN     NaN        NaN
# s1231            Aidan Gillen, Craig Kelly, Charlie Hunnam     NaN        NaN
#
#          release_year rating   duration  \
# show_id
# s21              2001   TV-Y   1 Season
# s845             2000   TV-G  2 Seasons
# s906             2001  TV-PG  7 Seasons
# ...

# %%
tv_df[(tv_df["release_year"] == 2000) & (tv_df["rating"] == "TV-G")].head()
# Out:
#             type                   title director  \
# show_id
# s845     TV Show       Supermarket Sweep      NaN
# s5766    TV Show  Timothy Goes To School      NaN
#
#                                                       cast country date_added  \
# show_id
# s845                                        David Ruprecht     NaN        NaN
# s5766    Austin Diiulio, Lisa Yamanaka, Fiona Reid, Max...     NaN        NaN
#
#          release_year rating   duration        listed_in  \
# show_id
# s845             2000   TV-G  2 Seasons       Unscripted
# s5766            2000   TV-G  2 Seasons  Animation, Kids
#
#                                                description
# show_id
# s845     Teams answer questions to earn time and advant...
# s5766    This animated series chronicles the adventures...

# %%
movie_df["director"].value_counts()
# Out:
# Mark Knight              113
# Cannis Holder             61
# Moonbug Entertainment     37
# Jay Chapman               34
# Arthur van Merwijk        30
#                         ...
# Andrew Traucki             1
# Karyn Kusama               1
# K. Subash                  1
# Robert Cuffley             1
# Steve Barker               1
# Name: director, Length: 5774, dtype: int64

# %%
movie_df.groupby("director").mean("duration_min")[["duration_min"]].sort_values("duration_min",ascending=False)
# Out:
#                        duration_min
# director
# Larry Peerce                  269.0
# Jim Wilmer                    224.5
# Ron Howard                    207.0
# St. Joseph Nwanze             188.0
# Franklin J. Schaffner         188.0
# ...                             ...
# Test title                      1.0
# Test Director US                0.0
# Test Director                   0.0
# Tester                          0.0
# Lewis Seiler                    0.0
#
# [5774 rows x 1 columns]

# %%
movie_df.loc[movie_df["director"] == "Larry Peerce"]
# Out:
#           type                 title      director  \
# show_id
# s8058    Movie  A Woman Named Jackie  Larry Peerce
#
#                                                       cast country date_added  \
# show_id
# s8058    Sarah Michelle Gellar, Andy Buckley, Stephen C...     NaN        NaN
#
#          release_year rating duration listed_in  \
# show_id
# s8058            1991    16+  269 min     Drama
#
#                                                description  duration_min
# show_id
# s8058    This starts when Jackie Kennedy was working af...           269

# %%
movie_df["duration_min"].max()
# Out:
# 601

# %%
movie_df.loc[movie_df["duration_min"] == movie_df["duration_min"].max()]["description"][0]
# Out:
# 'Black screen reduces the blue-spectrum light waves-known to inhibit REM sleep. Awaken rested and refreshed. Accompanied by the relaxing ocean surf and natural sounds filmed on location in the remote Centerville Beach near the California Redwoods. Great for children, pets and anyone with sleep issues. For best results adjust your monitor or TV to the night or darkest screen setting.'

# %%
amz.head(2)
# Out:
#           type                 title      director  \
# show_id
# s1       Movie   The Grand Seduction  Don McKellar
# s2       Movie  Take Care Good Night  Girish Joshi
#
#                                                      cast country  \
# show_id
# s1         Brendan Gleeson, Taylor Kitsch, Gordon Pinsent  Canada
# s2       Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar   India
#
#              date_added  release_year rating duration             listed_in  \
# show_id
# s1       March 30, 2021          2014    NaN  113 min         Comedy, Drama
# s2       March 30, 2021          2018    13+  110 min  Drama, International
#
#                                                description
# show_id
# s1       A small fishing village must procure a local d...
# s2       A Metro Family decides to fight a Cyber Crimin...

# %% [markdown]
# 1) Find the Count of all programs by Country
#
# 2) Find the oldest and newest programs
#
# 3) Find the program(s) with the greatest gap between date_added and release year
#
# 4) Add an integer column for duration in minutes for movies, with a NaN for TV shows
#
# 5) Add an integer column for number of seasons of a TV show with a NaN for movies
#
# 6) Construct a query that can search for genres in listed_in

# %%
df = pd.read_csv("./amazon_prime_titles.csv")
df = df.set_index("show_id")
df.head()
# Out:
#           type                 title        director  \
# show_id
# s1       Movie   The Grand Seduction    Don McKellar
# s2       Movie  Take Care Good Night    Girish Joshi
# s3       Movie  Secrets of Deception     Josh Webber
# s4       Movie    Pink: Staying True  Sonia Anderson
# s5       Movie         Monster Maker    Giles Foster
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# s3       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# s4       Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# s5       Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#              date_added  release_year rating duration  \
# show_id
# s1       March 30, 2021          2014    NaN  113 min
# ...

# %%
# 1) Find the Count of all programs by Country
df["country"].value_counts()
# df.groupby(["country"]).count()[["show_id"]].sort_values(by="show_id",ascending=False)
# Out:
# United States                            253
# India                                    229
# United Kingdom                            28
# Canada                                    16
# United Kingdom, United States             12
#                                         ...
# United States, Germany, Brazil, Italy      1
# South Africa                               1
# Australia, United States, Germany          1
# Germany, Austria, United States            1
# Italy, Spain                               1
# Name: country, Length: 86, dtype: int64

# %%
# 2) Find the oldest and newest programs
df[(df["release_year"] == df["release_year"].min()) \
   | (df["release_year"] == df["release_year"].max())] \
   [["title", "release_year"]]
# Out:
#                                                 title  release_year
# show_id
# s84                                  Within Our Gates          1920
# s97                                          Wildlike          2021
# s114                                      White Tiger          2021
# s135     WGC-Dell Technologies Match Play Reveal Show          2021
# s152                                     War of Likes          2021
# ...                                               ...           ...
# s9656                           DaFUNdamentals Series          2021
# s9657                              Anaganaga Oka Nenu          2021
# s9661                              The Man in the Hat          2021
# s9663                                           River          2021
# s9667                         Maradona: Blessed Dream          2021
#
# [1445 rows x 2 columns]

# %%
# 3) Find the program(s) with the greatest gap between date_added and release year

# df[["date_added","release_year"]]
date_df = df.dropna(subset=["date_added"]).copy()

# %%
date_df["year_added"] = date_df["date_added"].str.split(", ", expand=True)[1].astype(int)

# %%
date_df["gap"] = date_df["year_added"] - date_df["release_year"]
date_df[date_df["gap"] == date_df["gap"].max()]
# Out:
#             type          title director  \
# show_id
# s554     TV Show  The Lucy Show      NaN
#
#                                                       cast country  \
# show_id
# s554     Lucille Ball, Vivian Vance, Gale Gordon, Jimmy...     NaN
#
#              date_added  release_year rating   duration listed_in  \
# show_id
# s554     March 30, 2021          1967    13+  3 Seasons    Comedy
#
#                                                description  year_added  gap
# show_id
# s554     After her husband's death, Lucy Carmichael, an...        2021   54

# %%
movie_df.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# ...

# %%
# 4) Add an integer column for duration in minutes for movies, with a NaN for TV shows
movie_df = df[df["type"] == "Movie"].copy()
movie_df["runtime_minutes"] = movie_df["duration"].str.split(expand=True)[0].astype(int)
movie_df.head()
# Out:
#           type                 title        director  \
# show_id
# s1       Movie   The Grand Seduction    Don McKellar
# s2       Movie  Take Care Good Night    Girish Joshi
# s3       Movie  Secrets of Deception     Josh Webber
# s4       Movie    Pink: Staying True  Sonia Anderson
# s5       Movie         Monster Maker    Giles Foster
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# s3       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# s4       Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# s5       Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#              date_added  release_year rating duration  \
# show_id
# s1       March 30, 2021          2014    NaN  113 min
# ...

# %%
movie_df[["runtime_minutes"]]
# Out:
#          runtime_minutes
# show_id
# s1                   113
# s2                   110
# s3                    74
# s4                    69
# s5                    45
# ...                  ...
# s9661                 96
# s9663                 93
# s9664                 60
# s9666                 90
# s9668                103
#
# [7814 rows x 1 columns]

# %%
df = pd.merge(left=df, right=movie_df[["runtime_minutes"]], how="left", on="show_id")
df
# Out:
#             type                    title         director  \
# show_id
# s1         Movie      The Grand Seduction     Don McKellar
# s2         Movie     Take Care Good Night     Girish Joshi
# s3         Movie     Secrets of Deception      Josh Webber
# s4         Movie       Pink: Staying True   Sonia Anderson
# s5         Movie            Monster Maker     Giles Foster
# ...          ...                      ...              ...
# s9664      Movie      Pride Of The Bowery  Joseph H. Lewis
# s9665    TV Show            Planet Patrol              NaN
# s9666      Movie                  Outpost     Steve Barker
# s9667    TV Show  Maradona: Blessed Dream              NaN
# s9668      Movie              Harry Brown    Daniel Barber
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
df["duration"].str.split(" ", expand=True)
# Out:
#            0        1
# show_id
# s1       113      min
# s2       110      min
# s3        74      min
# s4        69      min
# s5        45      min
# ...      ...      ...
# s9664     60      min
# s9665      4  Seasons
# s9666     90      min
# s9667      1   Season
# s9668    103      min
#
# [9668 rows x 2 columns]

# %%
df["runtime_seasons"] = np.nan
# df["runtime_seasons"] = df["duration"].str.split(" ", expand=True)
df.loc[df["type"] == "TV Show", "runtime_seasons"] = df["duration"].str.split(" ", expand=True)[0].astype(int)

# %%
df
# Out:
#             type                    title         director  \
# show_id
# s1         Movie      The Grand Seduction     Don McKellar
# s2         Movie     Take Care Good Night     Girish Joshi
# s3         Movie     Secrets of Deception      Josh Webber
# s4         Movie       Pink: Staying True   Sonia Anderson
# s5         Movie            Monster Maker     Giles Foster
# ...          ...                      ...              ...
# s9664      Movie      Pride Of The Bowery  Joseph H. Lewis
# s9665    TV Show            Planet Patrol              NaN
# s9666      Movie                  Outpost     Steve Barker
# s9667    TV Show  Maradona: Blessed Dream              NaN
# s9668      Movie              Harry Brown    Daniel Barber
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
df["listed_in"].unique()
# Out:
# array(['Comedy, Drama', 'Drama, International', 'Action, Drama, Suspense',
#        'Documentary', 'Drama, Fantasy', 'Fantasy, Kids',
#        'Documentary, Special Interest', 'Comedy',
#        'Action, Science Fiction, Suspense', 'Drama', 'Adventure, Kids',
#        'Horror, Suspense', 'Documentary, Sports',
#        'Horror, Science Fiction', 'Kids, Special Interest',
#        'Comedy, Talk Show and Variety', 'Science Fiction', 'Kids',
#        'Action, Anime, Comedy',
#        'Arts, Entertainment, and Culture, Comedy, Drama', 'TV Shows',
#        'Animation, Anime, Fantasy', 'Action, Adventure, Animation',
#        'Anime, Kids', 'Music Videos and Concerts', 'Drama, Suspense',
#        'Fitness, Special Interest',
#        'Faith and Spirituality, Special Interest', 'Special Interest',
#        'Fitness', 'Action, Military and War, Western',
#        'Arts, Entertainment, and Culture, Comedy, Talk Show and Variety',
#        'Action, Western', 'Documentary, Science Fiction',
# ...

# %%
df["genres"] = df["listed_in"].str.split(", ")
df
# Out:
#             type                    title         director  \
# show_id
# s1         Movie      The Grand Seduction     Don McKellar
# s2         Movie     Take Care Good Night     Girish Joshi
# s3         Movie     Secrets of Deception      Josh Webber
# s4         Movie       Pink: Staying True   Sonia Anderson
# s5         Movie            Monster Maker     Giles Foster
# ...          ...                      ...              ...
# s9664      Movie      Pride Of The Bowery  Joseph H. Lewis
# s9665    TV Show            Planet Patrol              NaN
# s9666      Movie                  Outpost     Steve Barker
# s9667    TV Show  Maradona: Blessed Dream              NaN
# s9668      Movie              Harry Brown    Daniel Barber
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
# 6) Construct a query that can search for genres in listed_in
df[df["listed_in"].str.contains("Anime")]
# Out:
#             type                                              title  \
# show_id
# s22      TV Show                          Zo Zo Zombie: Mini-Series
# s29      TV Show                                    Yu-Gi-Oh! Zexal
# s31      TV Show                                     Yu-Gi-Oh! 5D's
# s140       Movie            Welcome to the Space Show (English Dub)
# s184     TV Show                                       VINLAND SAGA
# ...          ...                                                ...
# s8943      Movie  Sound! Euphonium: The Movie - Welcome To The K...
# s9123      Movie                             Pokémon the Movie 2000
# s9308      Movie  Project A-ko 2: Plot of the Daitokuji Financia...
# s9417    TV Show         Tomorrow's Joe 2 (Original Japanese Audio)
# s9597      Movie         Haikara-San: Here Comes Miss Modern Part 1
#
#                                     director  \
# show_id
# s22                                      NaN
# ...

# %%
len(df)
# Out:
# 9668

# %%
df.__len__()
# Out:
# 9668

# %%
lst1 = [1,2,3]
lst1.__len__(), len(lst1)
# Out:
# (3, 3)
