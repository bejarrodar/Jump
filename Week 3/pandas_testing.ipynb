# %%
import pandas as pd
import numpy as np

# %%
apt_csv = pd.read_csv("amazon_prime_titles.csv")

# %%
apt_csv
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
apt_csv.loc[0]
# Out:
# show_id                                                        s1
# type                                                        Movie
# title                                         The Grand Seduction
# director                                             Don McKellar
# cast               Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# country                                                    Canada
# date_added                                         March 30, 2021
# release_year                                                 2014
# rating                                                        NaN
# duration                                                  113 min
# listed_in                                           Comedy, Drama
# description     A small fishing village must procure a local d...
# Name: 0, dtype: object

# %%
apt_csv.set_index("show_id",inplace=True)

# %%
apt_csv.head()
# Out:
#           type                 title        director  \
# show_id
# s1       Movie   The Grand Seduction    Don McKellar
# s2       Movie  Take Care Good Night    Girish Joshi
# s3       Movie  Secrets of Deception     Josh Webber
# s4       Movie    Pink: Staying True  Sonia Anderson
# s5       Movie         Monster Maker    Giles Foster
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# s3       Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# s4       Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# s5       Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#              date_added  release_year rating duration  \
# show_id
# s1       March 30, 2021          2014    NaN  113 min
# ...

# %%
apt_csv["type"].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
apt_csv.loc[apt_csv["type"] == "TV Show"]
# Out:
#             type                          title director  \
# show_id
# s18      TV Show                     Zoo Babies      NaN
# s19      TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# s21      TV Show                     Zoboomafoo      NaN
# s22      TV Show      Zo Zo Zombie: Mini-Series      NaN
# s24      TV Show                   ZeroZeroZero      NaN
# ...          ...                            ...      ...
# s9652    TV Show                     Glass Room      NaN
# s9656    TV Show          DaFUNdamentals Series      NaN
# s9662    TV Show                     Terrahawks      NaN
# s9665    TV Show                  Planet Patrol      NaN
# s9667    TV Show        Maradona: Blessed Dream      NaN
#
#                                                       cast country date_added  \
# show_id
# s18                             Narrator - Gillian Barlett     NaN        NaN
# s19                                        Zoë Coombs Marr     NaN        NaN
# ...

# %%
apt_df = apt_csv.copy()

# %%
apt_csv["duration_min"] = apt_df["duration"].str.split(expand=True)[0]

# %%
apt_csv
# Out:
#             type                    title         director  \
# show_id
# s1         Movie      The Grand Seduction     Don McKellar
# s2         Movie     Take Care Good Night     Girish Joshi
# s3         Movie     Secrets of Deception      Josh Webber
# s4         Movie       Pink: Staying True   Sonia Anderson
# s5         Movie            Monster Maker     Giles Foster
# ...          ...                      ...              ...
# s9664      Movie      Pride Of The Bowery  Joseph H. Lewis
# s9665    TV Show            Planet Patrol              NaN
# s9666      Movie                  Outpost     Steve Barker
# s9667    TV Show  Maradona: Blessed Dream              NaN
# s9668      Movie              Harry Brown    Daniel Barber
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
apt_csv["duration_min"] = apt_csv["duration_min"].astype(int)

# %%
apt_csv[apt_csv["duration_min"] >= 100]
# Out:
#           type                      title                     director  \
# show_id
# s1       Movie        The Grand Seduction                 Don McKellar
# s2       Movie       Take Care Good Night                 Girish Joshi
# s8       Movie               Grease Live!  Thomas Kail, Alex Rudzinski
# s20      Movie                        Zoe                Drake Doremus
# s37      Movie             You're Not You              George C. Wolfe
# ...        ...                        ...                          ...
# s9650    Movie                       Jack         Francis Ford Coppola
# s9653    Movie            Famo$o (4K UHD)               Pepsy Romanoff
# s9654    Movie  Date Night (Extended Cut)                   Shawn Levy
# s9657    Movie         Anaganaga Oka Nenu                     Vamshi P
# s9668    Movie                Harry Brown                Daniel Barber
#
#                                                       cast        country  \
# show_id
# ...

# %%
apt_csv[(apt_csv["release_year"] == 2001) | (apt_csv["release_year"] == 2000)]
# Out:
#             type               title                 director  \
# show_id
# s21      TV Show          Zoboomafoo                      NaN
# s60        Movie             Xchange              Allan Moyle
# s341       Movie              Ticker              Albert Pyun
# s342       Movie           Tick Tock             Kevin Tenney
# s374       Movie       The Zookeeper              Ralph Ziman
# ...          ...                 ...                      ...
# s9410      Movie       Almost Famous            Cameron Crowe
# s9471      Movie     A Monkey's Tale  Jean-Francois Laguionie
# s9496      Movie     Lured Innocence           Kikuo Kawasaki
# s9606      Movie           Bojangles           Joseph Sargent
# s9625      Movie  The Luzhin Defense           Marleen Gorris
#
#                                                       cast  \
# show_id
# s21                                                    NaN
# s60      Stephen Baldwin, Pascale Bussières, Kim Coates...
# ...

# %%
apt_csv["director"].value_counts().head(1)
# Out:
# Mark Knight    113
# Name: director, dtype: int64

# %%
apt_csv["cast"].str.split().value_counts()
# Out:
# [Maggie, Binkley]                                                                                                     56
# [1]                                                                                                                   34
# [Anne-Marie, Newland]                                                                                                 24
# [Cassandra, Peterson]                                                                                                 21
# [Grace, Tamayo,, Erin, Webbs]                                                                                         17
#                                                                                                                       ..
# [Lorena, Segura, York,, Garrett, Westton,, Bill, Engvall,, Bethany, Peterson,, Dariush, A., Moslemi]                   1
# [Toni, Collette,, Parker, Posey,, Lisa, Kudrow]                                                                        1
# ...

# %%
apt_csv.groupby("director").mean("duration_min")[["duration_min"]].sort_values("duration_min",ascending = False)
# Out:
#                        duration_min
# director
# Larry Peerce                  269.0
# Jim Wilmer                    224.5
# Ron Howard                    207.0
# St. Joseph Nwanze             188.0
# Franklin J. Schaffner         188.0
# ...                             ...
# Test title                      1.0
# Test Director US                0.0
# Test Director                   0.0
# Tester                          0.0
# Lewis Seiler                    0.0
#
# [5774 rows x 1 columns]

# %%
apt_csv.loc[apt_csv["duration_min"] == 601]
# Out:
#           type                                              title  \
# show_id
# s934     Movie  Soothing Surf at Del Norte for Sleep black screen
#
#             director cast country date_added  release_year rating duration  \
# show_id
# s934     Mark Knight  NaN     NaN        NaN          2018    ALL  601 min
#
#                 listed_in                                        description  \
# show_id
# s934     Special Interest  Black screen reduces the blue-spectrum light w...
#
#          duration_min
# show_id
# s934              601

# %%
apt_csv["country"].value_counts()
# Out:
# United States                            253
# India                                    229
# United Kingdom                            28
# Canada                                    16
# United Kingdom, United States             12
#                                         ...
# United States, Germany, Brazil, Italy      1
# South Africa                               1
# Australia, United States, Germany          1
# Germany, Austria, United States            1
# Italy, Spain                               1
# Name: country, Length: 86, dtype: int64

# %%
apt_csv.sort_values("release_year").head(10)
# Out:
#           type                                    title  \
# show_id
# s84      Movie                         Within Our Gates
# s1285    Movie                                Pollyanna
# s1475    Movie                      Nomads Of The North
# s1144    Movie                      Robin Hood (Silent)
# s1426    Movie                       One Exciting Night
# s1685    Movie                           Merry-Go-Round
# s1135    Movie                                   Romola
# s8591    Movie                              Tumbleweeds
# s2630    Movie             Don Q, Son of Zorro (Silent)
# s6628    Movie  Sir Arthur Conan Doyle's The Lost World
#
#                                  director  \
# show_id
# s84                        Oscar Micheaux
# s1285                         Paul Powell
# s1475                      David Hartford
# s1144                          Allan Dwan
# s1426                       D.W. Griffith
# s1685    Rupert Julian, Eric von Stroheim
# ...

# %%
apt_csv.sort_values("release_year",ascending=False).head(10)
# Out:
#             type                               title  \
# show_id
# s5439      Movie                          No Strings
# s5544      Movie                      Deadly Passion
# s6235      Movie  Go to School and Learn with Blippi
# s6835      Movie     Where is Chicky? - Chapter Five
# s8009      Movie                        Sema Thimiru
# s7132      Movie                          Urban Envy
# s8002      Movie                     Tappinchukoleru
# s1242      Movie              Pungo - A Witch's Tale
# s8938      Movie                 3 Pints and a Rabbi
# s3332    TV Show     Alien Conspiracy: They Are Here
#
#                            director  \
# show_id
# s5439                   Rebecca Ugo
# s5544         Jasmine  Jamar Alston
# s6235                   Stevin John
# s6835               William Hoareau
# s8009                 Nandha kishor
# s7132    Coke Horner, Desmond Weems
# s8002          Rudrapatla Venugopal
# s1242                   Philip Cook
# ...

# %%
apt_csv["year_added"] = apt_df["date_added"].str.split(expand=True)[2].astype(int,errors="ignore")

# %%
apt_csv
# Out:
#             type                    title         director  \
# show_id
# s1         Movie      The Grand Seduction     Don McKellar
# s2         Movie     Take Care Good Night     Girish Joshi
# s3         Movie     Secrets of Deception      Josh Webber
# s4         Movie       Pink: Staying True   Sonia Anderson
# s5         Movie            Monster Maker     Giles Foster
# ...          ...                      ...              ...
# s9664      Movie      Pride Of The Bowery  Joseph H. Lewis
# s9665    TV Show            Planet Patrol              NaN
# s9666      Movie                  Outpost     Steve Barker
# s9667    TV Show  Maradona: Blessed Dream              NaN
# s9668      Movie              Harry Brown    Daniel Barber
#
#                                                       cast         country  \
# show_id
# s1          Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# s2        Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# ...

# %%
apt_csv["year_added"].astype(int,errors="ignore")
# Out:
# show_id
# s1       2021
# s2       2021
# s3       2021
# s4       2021
# s5       2021
#          ...
# s9664     NaN
# s9665     NaN
# s9666     NaN
# s9667     NaN
# s9668     NaN
# Name: year_added, Length: 9668, dtype: object

# %%
np.array( [ [ 1 ] , [ 1 , 2 ] , [ 1 , 2 , 3 ] ] ).dtype
# Out:
# C:\Users\Jarrod Caplan\AppData\Local\Temp\ipykernel_8804\1663260307.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array( [ [ 1 ] , [ 1 , 2 ] , [ 1 , 2 , 3 ] ] ).dtype
# dtype('O')
